# %%
import scmomentum as scm

# %% [markdown]
# ### Input settings
#
# Set the path to the AnnData object and the column in `adata.var` used to cluster the cells.

# %%
global group
group = 'leiden'
adata_path = "/Users/larisamorales/Documents/KAUST/scgrn-project/objects/scvelo/sDG20k-adata.pkl"

# %% [markdown]
# ##### Note : How to save an AnnData object?
#
# After running all the steps in scVelo you can simply run
#
# `scm.utilities.save_adata(filename.pkl)`
#
# to save your final AnnData object into a `pkl` file that `scMomentum` can read.

# %% [markdown]
# ### Load AnnData
#
# Previously saved with `pickle`

# %%
adata = scm.utilities.load_adata(adata_path)

# %% [markdown]
# ### Pre-processing
#
# Compute cluster expression distances and then remove genes with NaN velocities

# %%
adata = scm.network_inference.preprocess(adata,group)
# Out:
# Trying to set attribute `.var` of view, copying.

# %% [markdown]
# ### Network inference
#
# Predicting GRN for each cluster according to the gene ranking method specified in `mode` and the size of the network indicated in `size`. The network of each cluster will be stored in `adata.uns[mode-size][cluster]`

# %%
clusters = list(set(adata.obs[group]))
mode = 'highexp'
size = 100

for cluster in clusters:
    scm.network_inference.predict_network(adata,cluster,mode,size,group)

# %%
adata.uns[mode+'-'+str(size)][clusters[0]]
# Out:
#                  geneTarget88  geneHK89  geneHK199  geneHK158  geneHK245  \
# geneTarget88         1.760942  0.005547  -0.001829  -0.000128  -0.001891
# geneHK89            -0.024174  0.321460  -0.000601   0.000813   0.001394
# geneHK199           -0.011284 -0.000289   0.326107  -0.000951   0.002357
# geneHK158            0.042158 -0.006627  -0.012888   0.258069  -0.005416
# geneHK245            0.009605  0.011855   0.000725   0.000799   0.246822
# ...                       ...       ...        ...        ...        ...
# geneHK163           -0.003408  0.004386   0.000542   0.004389   0.003130
# geneHK56             0.033862 -0.008632  -0.000012   0.000586  -0.000654
# geneleft_A1_TF1     -0.036457 -0.000337   0.005452   0.006437   0.004492
# geneTarget140        0.021799 -0.014157   0.013677   0.002773   0.003799
# geneHK125            0.003190 -0.005282   0.006327   0.004313   0.013707
#
#                   geneHK9  geneTarget22  geneHK160  geneHK18  geneHK222  ...  \
# geneTarget88     0.000542      0.023117   0.004779 -0.006063   0.000541  ...
# geneHK89         0.003052     -0.019603  -0.000873  0.000614  -0.000275  ...
# geneHK199        0.000968      0.024532  -0.000415 -0.003239   0.000371  ...
# geneHK158        0.003004     -0.015077  -0.008127 -0.002157  -0.004195  ...
# geneHK245       -0.010014     -0.003116   0.000311  0.001945   0.001564  ...
# ...                   ...           ...        ...       ...        ...  ...
# geneHK163       -0.010993      0.021145  -0.000473  0.002091   0.006052  ...
# geneHK56         0.002181     -0.003621  -0.009501  0.000667   0.006538  ...
# geneleft_A1_TF1 -0.004581     -0.000667   0.007151  0.005736  -0.001664  ...
# geneTarget140    0.001067     -0.004166   0.004418  0.002066  -0.001524  ...
# geneHK125        0.000872     -0.018547   0.008963  0.001699  -0.001174  ...
#
#                  geneTarget164  geneTarget54  geneTarget84  geneHK107  \
# geneTarget88          0.001363      0.005122      0.010331  -0.000095
# geneHK89             -0.001515      0.003816      0.002601  -0.000134
# geneHK199            -0.006092     -0.000239      0.011913  -0.000289
# geneHK158            -0.003363      0.001672     -0.000730   0.001464
# geneHK245            -0.018566      0.002476      0.012144  -0.000885
# ...                        ...           ...           ...        ...
# geneHK163             0.001631     -0.013990      0.003620   0.000506
# geneHK56              0.010471     -0.013080      0.001899  -0.001944
# geneleft_A1_TF1      -0.006372      0.004318     -0.008915   0.002324
# geneTarget140         0.013065      0.016928     -0.017848   0.002051
# geneHK125            -0.003232      0.006705      0.025450   0.004091
#
#                  geneTarget65  geneHK163  geneHK56  geneleft_A1_TF1  \
# geneTarget88        -0.000795  -0.000793  0.004433        -0.012337
# geneHK89            -0.002572  -0.006659  0.004144         0.014658
# geneHK199            0.001241   0.001962  0.002697        -0.003948
# geneHK158            0.003201  -0.003495 -0.000721        -0.015487
# geneHK245           -0.001485   0.002850  0.004161        -0.006119
# ...                       ...        ...       ...              ...
# geneHK163            0.001694   0.419832  0.002287         0.002980
# geneHK56             0.001548   0.005605  0.300685        -0.017485
# geneleft_A1_TF1      0.002562  -0.000839  0.000835         0.546604
# geneTarget140        0.000602   0.001659 -0.006220         0.010844
# geneHK125           -0.006351  -0.007089  0.008525         0.000219
#
#                  geneTarget140  geneHK125
# geneTarget88          0.003517  -0.003411
# geneHK89              0.001012   0.000337
# geneHK199             0.003998   0.002609
# geneHK158            -0.016497   0.003175
# geneHK245             0.003523  -0.002107
# ...                        ...        ...
# geneHK163             0.007370  -0.000947
# geneHK56             -0.003039  -0.003343
# geneleft_A1_TF1      -0.002330   0.000176
# geneTarget140         0.452258   0.004231
# geneHK125             0.005487   0.319325
#
# [100 rows x 100 columns]
